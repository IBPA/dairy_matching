# %%
import pandas as pd

# %%
ncc_data = pd.read_csv('../data/NCC_2018_nutrients_per_100g_originalcolnames.txt',sep='\t')

# %%
ncc_data.head()
# Out:
#    Food ID           Keylist                                 Food Description  \
# 0    21553           BABY.AC                    baby food, apples and chicken
# 1    16517          BABY.ANI                       baby food, animal crackers
# 2   118780          BABY.BAR                            baby food, cereal bar
# 3    16518          BABY.BRE                           baby food, breast milk
# 4   118008  BABY.CER.DRY.BAR  baby food, cereal, instant - unprepared, barley
#
#                       Short Food Description Food Type  \
# 0              Baby food, apples and chicken         X
# 1      Baby food, animal crackers - cinnamon         X
# 2                      Baby food, cereal bar         X
# 3                                Breast milk         C
# 4  Baby food, barley cereal, dry, unprepared         X
#
#                     NCC Food Group                    NCC Food Group Category  \
# 0  Meat, poultry, and fish recipes                    Meat, fish, and poultry
# ...
